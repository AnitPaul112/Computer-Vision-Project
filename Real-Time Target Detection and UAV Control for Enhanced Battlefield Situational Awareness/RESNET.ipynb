# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.image import resize
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
data_dir = '/content/drive/MyDrive/DATASET'
classes = ['tank,soldiers', 'base,plane']

# %%
# Load and preprocess image data
def load_and_preprocess_data(data_dir, classes, target_shape=(128, 128)):
    data = []
    labels = []

    for i, class_name in enumerate(classes):
        class_dir = os.path.join(data_dir, class_name)
        for filename in os.listdir(class_dir):
            if filename.endswith('.jpg'):
                file_path = os.path.join(class_dir, filename)
                # Load and preprocess the image
                img = load_img(file_path, target_size=target_shape)
                img_array = img_to_array(img)
                data.append(img_array)
                labels.append(i)

    return np.array(data), np.array(labels)

# Split data into training and testing sets
data, labels = load_and_preprocess_data(data_dir, classes)
labels = to_categorical(labels, num_classes=len(classes))  # Convert labels to one-hot encoding
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
def load_and_preprocess_data(data_dir, classes, target_shape=(224, 224)):
    data = []
    labels = []

    for i, class_name in enumerate(classes):
        class_dir = os.path.join(data_dir, class_name)
        for filename in os.listdir(class_dir):
            if filename.endswith('.jpg'):
                file_path = os.path.join(class_dir, filename)
                # Load and preprocess the image
                img = load_img(file_path, target_size=target_shape)
                img_array = preprocess_input(img_to_array(img))  # Preprocessing for ResNet
                data.append(img_array)
                labels.append(i)

    return np.array(data), np.array(labels)

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Input, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

# Define input shape
input_shape = X_train[0].shape

# Load the ResNet50 model without the top layer and with pre-trained ImageNet weights
resnet_base = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)

# Freeze the ResNet base layers to retain pre-trained features
resnet_base.trainable = False

# Add custom layers on top
x = GlobalAveragePooling2D()(resnet_base.output)  # Global Average Pooling instead of Flatten
x = Dense(64, activation='relu')(x)  # Fully connected layer
output_layer = Dense(len(classes), activation='softmax')(x)  # Output layer for classification

# Create the complete model
model = Model(inputs=resnet_base.input, outputs=output_layer)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_test, y_test)
)

# Evaluate the model on the test set
test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy[1]}')

# Save the model
model.save('resnet50_classification_model.h5')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_pad (ZeroPadding2D) │ (None, 134, 134, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_conv (Conv2D)       │ (None, 64, 64, 64)     │          9,472 │ conv1_pad[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_bn                  │ (None, 64, 64, 64)     │            256 │ conv1_conv[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_relu (Activation)   │ (None, 64, 64, 64)     │              0 │ conv1_bn[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool1_pad (ZeroPadding2D) │ (None, 66, 66, 64)     │              0 │ conv1_relu[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool1_pool (MaxPooling2D) │ (None, 32, 32, 64)     │              0 │ pool1_pad[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_conv       │ (None, 32, 32, 64)     │          4,160 │ pool1_pool[0][0]       │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_bn         │ (None, 32, 32, 64)     │            256 │ conv2_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_relu       │ (None, 32, 32, 64)     │              0 │ conv2_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_conv       │ (None, 32, 32, 64)     │         36,928 │ conv2_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_bn         │ (None, 32, 32, 64)     │            256 │ conv2_block1_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_relu       │ (None, 32, 32, 64)     │              0 │ conv2_block1_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_conv       │ (None, 32, 32, 256)    │         16,640 │ pool1_pool[0][0]       │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_3_conv       │ (None, 32, 32, 256)    │         16,640 │ conv2_block1_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_bn         │ (None, 32, 32, 256)    │          1,024 │ conv2_block1_0_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_3_bn         │ (None, 32, 32, 256)    │          1,024 │ conv2_block1_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_add (Add)    │ (None, 32, 32, 256)    │              0 │ conv2_block1_0_bn[0][… │
# │                           │                        │                │ conv2_block1_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_out          │ (None, 32, 32, 256)    │              0 │ conv2_block1_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_conv       │ (None, 32, 32, 64)     │         16,448 │ conv2_block1_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_bn         │ (None, 32, 32, 64)     │            256 │ conv2_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_relu       │ (None, 32, 32, 64)     │              0 │ conv2_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_conv       │ (None, 32, 32, 64)     │         36,928 │ conv2_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_bn         │ (None, 32, 32, 64)     │            256 │ conv2_block2_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_relu       │ (None, 32, 32, 64)     │              0 │ conv2_block2_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_3_conv       │ (None, 32, 32, 256)    │         16,640 │ conv2_block2_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_3_bn         │ (None, 32, 32, 256)    │          1,024 │ conv2_block2_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_add (Add)    │ (None, 32, 32, 256)    │              0 │ conv2_block1_out[0][0… │
# │                           │                        │                │ conv2_block2_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_out          │ (None, 32, 32, 256)    │              0 │ conv2_block2_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_conv       │ (None, 32, 32, 64)     │         16,448 │ conv2_block2_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_bn         │ (None, 32, 32, 64)     │            256 │ conv2_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_relu       │ (None, 32, 32, 64)     │              0 │ conv2_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_conv       │ (None, 32, 32, 64)     │         36,928 │ conv2_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_bn         │ (None, 32, 32, 64)     │            256 │ conv2_block3_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_relu       │ (None, 32, 32, 64)     │              0 │ conv2_block3_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_3_conv       │ (None, 32, 32, 256)    │         16,640 │ conv2_block3_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_3_bn         │ (None, 32, 32, 256)    │          1,024 │ conv2_block3_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_add (Add)    │ (None, 32, 32, 256)    │              0 │ conv2_block2_out[0][0… │
# │                           │                        │                │ conv2_block3_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_out          │ (None, 32, 32, 256)    │              0 │ conv2_block3_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_conv       │ (None, 16, 16, 128)    │         32,896 │ conv2_block3_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_conv       │ (None, 16, 16, 128)    │        147,584 │ conv3_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block1_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block1_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_conv       │ (None, 16, 16, 512)    │        131,584 │ conv2_block3_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_3_conv       │ (None, 16, 16, 512)    │         66,048 │ conv3_block1_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_bn         │ (None, 16, 16, 512)    │          2,048 │ conv3_block1_0_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_3_bn         │ (None, 16, 16, 512)    │          2,048 │ conv3_block1_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_add (Add)    │ (None, 16, 16, 512)    │              0 │ conv3_block1_0_bn[0][… │
# │                           │                        │                │ conv3_block1_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_out          │ (None, 16, 16, 512)    │              0 │ conv3_block1_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_conv       │ (None, 16, 16, 128)    │         65,664 │ conv3_block1_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_conv       │ (None, 16, 16, 128)    │        147,584 │ conv3_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block2_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block2_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_3_conv       │ (None, 16, 16, 512)    │         66,048 │ conv3_block2_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_3_bn         │ (None, 16, 16, 512)    │          2,048 │ conv3_block2_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_add (Add)    │ (None, 16, 16, 512)    │              0 │ conv3_block1_out[0][0… │
# │                           │                        │                │ conv3_block2_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_out          │ (None, 16, 16, 512)    │              0 │ conv3_block2_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_conv       │ (None, 16, 16, 128)    │         65,664 │ conv3_block2_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_2_conv       │ (None, 16, 16, 128)    │        147,584 │ conv3_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_2_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block3_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_2_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block3_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_3_conv       │ (None, 16, 16, 512)    │         66,048 │ conv3_block3_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_3_bn         │ (None, 16, 16, 512)    │          2,048 │ conv3_block3_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_add (Add)    │ (None, 16, 16, 512)    │              0 │ conv3_block2_out[0][0… │
# │                           │                        │                │ conv3_block3_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_out          │ (None, 16, 16, 512)    │              0 │ conv3_block3_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_conv       │ (None, 16, 16, 128)    │         65,664 │ conv3_block3_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block4_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block4_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_2_conv       │ (None, 16, 16, 128)    │        147,584 │ conv3_block4_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_2_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block4_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_2_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block4_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_3_conv       │ (None, 16, 16, 512)    │         66,048 │ conv3_block4_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_3_bn         │ (None, 16, 16, 512)    │          2,048 │ conv3_block4_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_add (Add)    │ (None, 16, 16, 512)    │              0 │ conv3_block3_out[0][0… │
# │                           │                        │                │ conv3_block4_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_out          │ (None, 16, 16, 512)    │              0 │ conv3_block4_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_1_conv       │ (None, 8, 8, 256)      │        131,328 │ conv3_block4_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_1_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_1_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_2_conv       │ (None, 8, 8, 256)      │        590,080 │ conv4_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_2_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block1_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_2_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block1_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_0_conv       │ (None, 8, 8, 1024)     │        525,312 │ conv3_block4_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_3_conv       │ (None, 8, 8, 1024)     │        263,168 │ conv4_block1_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_0_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block1_0_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_3_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block1_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_add (Add)    │ (None, 8, 8, 1024)     │              0 │ conv4_block1_0_bn[0][… │
# │                           │                        │                │ conv4_block1_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_out          │ (None, 8, 8, 1024)     │              0 │ conv4_block1_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_1_conv       │ (None, 8, 8, 256)      │        262,400 │ conv4_block1_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_1_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_1_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_2_conv       │ (None, 8, 8, 256)      │        590,080 │ conv4_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_2_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block2_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_2_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block2_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_3_conv       │ (None, 8, 8, 1024)     │        263,168 │ conv4_block2_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_3_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block2_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_add (Add)    │ (None, 8, 8, 1024)     │              0 │ conv4_block1_out[0][0… │
# │                           │                        │                │ conv4_block2_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_out          │ (None, 8, 8, 1024)     │              0 │ conv4_block2_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_conv       │ (None, 8, 8, 256)      │        262,400 │ conv4_block2_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_2_conv       │ (None, 8, 8, 256)      │        590,080 │ conv4_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_2_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block3_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_2_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block3_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_3_conv       │ (None, 8, 8, 1024)     │        263,168 │ conv4_block3_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_3_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block3_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_add (Add)    │ (None, 8, 8, 1024)     │              0 │ conv4_block2_out[0][0… │
# │                           │                        │                │ conv4_block3_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_out          │ (None, 8, 8, 1024)     │              0 │ conv4_block3_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_conv       │ (None, 8, 8, 256)      │        262,400 │ conv4_block3_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block4_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block4_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_2_conv       │ (None, 8, 8, 256)      │        590,080 │ conv4_block4_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_2_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block4_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_2_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block4_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_3_conv       │ (None, 8, 8, 1024)     │        263,168 │ conv4_block4_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_3_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block4_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_add (Add)    │ (None, 8, 8, 1024)     │              0 │ conv4_block3_out[0][0… │
# │                           │                        │                │ conv4_block4_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_out          │ (None, 8, 8, 1024)     │              0 │ conv4_block4_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_1_conv       │ (None, 8, 8, 256)      │        262,400 │ conv4_block4_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_1_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block5_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_1_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block5_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_2_conv       │ (None, 8, 8, 256)      │        590,080 │ conv4_block5_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_2_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block5_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_2_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block5_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_3_conv       │ (None, 8, 8, 1024)     │        263,168 │ conv4_block5_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_3_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block5_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_add (Add)    │ (None, 8, 8, 1024)     │              0 │ conv4_block4_out[0][0… │
# │                           │                        │                │ conv4_block5_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_out          │ (None, 8, 8, 1024)     │              0 │ conv4_block5_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_conv       │ (None, 8, 8, 256)      │        262,400 │ conv4_block5_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block6_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block6_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_conv       │ (None, 8, 8, 256)      │        590,080 │ conv4_block6_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block6_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block6_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_3_conv       │ (None, 8, 8, 1024)     │        263,168 │ conv4_block6_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_3_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block6_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_add (Add)    │ (None, 8, 8, 1024)     │              0 │ conv4_block5_out[0][0… │
# │                           │                        │                │ conv4_block6_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_out          │ (None, 8, 8, 1024)     │              0 │ conv4_block6_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_1_conv       │ (None, 4, 4, 512)      │        524,800 │ conv4_block6_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_1_bn         │ (None, 4, 4, 512)      │          2,048 │ conv5_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_1_relu       │ (None, 4, 4, 512)      │              0 │ conv5_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_2_conv       │ (None, 4, 4, 512)      │      2,359,808 │ conv5_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_2_bn         │ (None, 4, 4, 512)      │          2,048 │ conv5_block1_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_2_relu       │ (None, 4, 4, 512)      │              0 │ conv5_block1_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_0_conv       │ (None, 4, 4, 2048)     │      2,099,200 │ conv4_block6_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_3_conv       │ (None, 4, 4, 2048)     │      1,050,624 │ conv5_block1_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_0_bn         │ (None, 4, 4, 2048)     │          8,192 │ conv5_block1_0_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_3_bn         │ (None, 4, 4, 2048)     │          8,192 │ conv5_block1_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_add (Add)    │ (None, 4, 4, 2048)     │              0 │ conv5_block1_0_bn[0][… │
# │                           │                        │                │ conv5_block1_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_out          │ (None, 4, 4, 2048)     │              0 │ conv5_block1_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_1_conv       │ (None, 4, 4, 512)      │      1,049,088 │ conv5_block1_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_1_bn         │ (None, 4, 4, 512)      │          2,048 │ conv5_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_1_relu       │ (None, 4, 4, 512)      │              0 │ conv5_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_2_conv       │ (None, 4, 4, 512)      │      2,359,808 │ conv5_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_2_bn         │ (None, 4, 4, 512)      │          2,048 │ conv5_block2_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_2_relu       │ (None, 4, 4, 512)      │              0 │ conv5_block2_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_3_conv       │ (None, 4, 4, 2048)     │      1,050,624 │ conv5_block2_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_3_bn         │ (None, 4, 4, 2048)     │          8,192 │ conv5_block2_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_add (Add)    │ (None, 4, 4, 2048)     │              0 │ conv5_block1_out[0][0… │
# │                           │                        │                │ conv5_block2_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_out          │ (None, 4, 4, 2048)     │              0 │ conv5_block2_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_1_conv       │ (None, 4, 4, 512)      │      1,049,088 │ conv5_block2_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_1_bn         │ (None, 4, 4, 512)      │          2,048 │ conv5_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_1_relu       │ (None, 4, 4, 512)      │              0 │ conv5_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_2_conv       │ (None, 4, 4, 512)      │      2,359,808 │ conv5_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_2_bn         │ (None, 4, 4, 512)      │          2,048 │ conv5_block3_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_2_relu       │ (None, 4, 4, 512)      │              0 │ conv5_block3_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_3_conv       │ (None, 4, 4, 2048)     │      1,050,624 │ conv5_block3_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_3_bn         │ (None, 4, 4, 2048)     │          8,192 │ conv5_block3_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_add (Add)    │ (None, 4, 4, 2048)     │              0 │ conv5_block2_out[0][0… │
# │                           │                        │                │ conv5_block3_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_out          │ (None, 4, 4, 2048)     │              0 │ conv5_block3_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 2048)           │              0 │ conv5_block3_out[0][0] │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 64)             │        131,136 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 2)              │            130 │ dense[0][0]            │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 23,718,978 (90.48 MB)
#  Trainable params: 131,266 (512.76 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 178s 3s/step - accuracy: 0.6933 - loss: 0.6332 - val_accuracy: 0.7445 - val_loss: 0.5498
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - accuracy: 0.8179 - loss: 0.3867 - val_accuracy: 0.7545 - val_loss: 0.5469
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 203s 3s/step - accuracy: 0.8714 - loss: 0.3191 - val_accuracy: 0.7385 - val_loss: 0.5772
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 203s 3s/step - accuracy: 0.9098 - loss: 0.2262 - val_accuracy: 0.7625 - val_loss: 0.5744
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - accuracy: 0.9420 - loss: 0.1726 - val_accuracy: 0.7405 - val_loss: 0.6828
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 170s 3s/step - accuracy: 0.9472 - loss: 0.1516 - val_accuracy: 0.7465 - val_loss: 0.6560
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - accuracy: 0.9764 - loss: 0.1014 - val_accuracy: 0.7645 - val_loss: 0.7152
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 189s 2s/step - accuracy: 0.9793 - loss: 0.0847 - val_accuracy: 0.7685 - val_loss: 0.7359
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - accuracy: 0.9878 - loss: 0.0539 - val_accuracy: 0.7784 - val_loss: 0.7956
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - accuracy: 0.9844 - loss: 0.0682 - val_accuracy: 0.7745 - val_loss: 0.7814
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 202s 3s/step - accuracy: 0.9957 - loss: 0.0367 - val_accuracy: 0.7625 - val_loss: 0.8316
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 200s 3s/step - accuracy: 0.9937 - loss: 0.0260 - val_accuracy: 0.7665 - val_loss: 0.8794
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - accuracy: 0.9928 - loss: 0.0226 - val_accuracy: 0.7645 - val_loss: 0.8758
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 191s 2s/step - accuracy: 0.9959 - loss: 0.0204 - val_accuracy: 0.7685 - val_loss: 0.9560
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 156s 2s/step - accuracy: 0.9965 - loss: 0.0316 - val_accuracy: 0.7565 - val_loss: 0.9626
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 164s 3s/step - accuracy: 0.9988 - loss: 0.0091 - val_accuracy: 0.7764 - val_loss: 0.9847
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 155s 2s/step - accuracy: 0.9958 - loss: 0.0165 - val_accuracy: 0.7745 - val_loss: 0.9956
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 165s 3s/step - accuracy: 0.9967 - loss: 0.0226 - val_accuracy: 0.7625 - val_loss: 1.0364
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 203s 3s/step - accuracy: 0.9995 - loss: 0.0085 - val_accuracy: 0.7625 - val_loss: 1.0423
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 207s 3s/step - accuracy: 0.9995 - loss: 0.0048 - val_accuracy: 0.7745 - val_loss: 1.0851
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test accuracy: 0.7744510769844055

# %%
import matplotlib.pyplot as plt

# Plot the accuracy graph
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import os
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
import glob

# Load your pre-trained model (ResNet50)
model = load_model('resnet50_classification_model.h5')

# Define the target shape as the shape used during training (128, 128)
target_shape = (128, 128)  # Adjust this to your model's expected input shape

# Define your class labels
classes = ['base,plane', 'tank,soldiers']

# Preprocessing function for ResNet50
def preprocess_for_resnet50(img_array):
    return preprocess_input(img_array)

# Function to classify a single image
def test_image(file_path, model):
    try:
        # Load and preprocess the image
        img = load_img(file_path, target_size=target_shape)  # Ensure target size matches training input size
        img_array = img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
        img_array = preprocess_for_resnet50(img_array)  # Preprocessing step for ResNet50

        # Predict the class probabilities
        predictions = model.predict(img_array)

        # Get class probabilities for the first image in the batch (if batch processing)
        class_probabilities = predictions[0]

        # Get the index of the predicted class
        predicted_class_index = np.argmax(class_probabilities)

        # Get the name of the predicted class
        predicted_class = classes[predicted_class_index]

        return predicted_class, class_probabilities
    except Exception as e:
        print(f"Error processing image {file_path}: {e}")
        return None, None

# Function to classify all images in a folder
def classify_images_in_folder(folder_path, model):
    # Generate a list of image files in the folder (handle .jpg and other formats)
    image_files = glob.glob(os.path.join(folder_path, '*.jpg'))

    if not image_files:
        print("No images found in the specified directory.")
        return

    # Loop over all images in the folder
    for filename in image_files:
        print(f"\nProcessing image: {os.path.basename(filename)}")
        predicted_class, class_probabilities = test_image(filename, model)

        if predicted_class:
            print(f"Predicted Class: {predicted_class}")
            for i, class_label in enumerate(classes):
                probability = class_probabilities[i]
                print(f'  Class: {class_label}, Probability: {probability:.4f}')
        else:
            print(f"Skipped processing image: {filename} due to an error")

# Define folder path with test images (modify this path with the location of your images)
test_images_folder = '/content/drive/MyDrive/DATASET/test'  # Modify as necessary

# Call the function to classify all images in the folder
print("\nClassifying images in the folder:")
classify_images_in_folder(test_images_folder, model)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Classifying images in the folder:
#
# Processing image: img553_jpg.rf.a81868ed6c6253037b2a0f41f7d14e69.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img1920_jpg.rf.82588fa23b4418017835d085989683b6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9999
#   Class: tank,soldiers, Probability: 0.0001
#
# Processing image: mg144_jpg.rf.25d2f10522edf2aec453623d51c0f6d3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img0_jpg.rf.7d902340a5db3d37a362a2cbdd38a536.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img847_jpg.rf.b1d286a18f315d07226b8ed470c67fbf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9992
#   Class: tank,soldiers, Probability: 0.0008
#
# Processing image: mg105_jpg.rf.fe078045e8b21a9088e325c1642462e5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0039
#   Class: tank,soldiers, Probability: 0.9961
#
# Processing image: img1086_jpg.rf.065df8e972b9ba694976c018d422650e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0446
#   Class: tank,soldiers, Probability: 0.9554
#
# Processing image: mg266_jpg.rf.7915a4121d844c15f4c27293983bae07.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0003
#   Class: tank,soldiers, Probability: 0.9997
#
# Processing image: img627_jpg.rf.e8cbff6163e69a4a731571d05bb3df63.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9999
#   Class: tank,soldiers, Probability: 0.0001
#
# Processing image: img980_jpg.rf.0558a801a2b4cda479832fd8b255da6e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.1005
#   Class: tank,soldiers, Probability: 0.8995
#
# Processing image: img380_jpg.rf.667b4a26dfe7f592a0f3cda7828c6424.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0021
#   Class: tank,soldiers, Probability: 0.9979
#
# Processing image: img432_jpg.rf.ce2c4238541c1c1b23de3ca130e7809b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.5268
#   Class: tank,soldiers, Probability: 0.4732
#
# Processing image: img922_jpg.rf.650652d694184b93a23cc1b235538dff.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.7217
#   Class: tank,soldiers, Probability: 0.2783
#
# Processing image: img1024_jpg.rf.a6f7e5b4399ee61935e37229ad0d7f62.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img462_jpg.rf.111c406923a0b8494118a83eb571a29f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0001
#   Class: tank,soldiers, Probability: 0.9999
#
# Processing image: img747_jpg.rf.764cb1a7e6c2ec40e1a445ce17a0f713.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.3051
#   Class: tank,soldiers, Probability: 0.6949
#
# Processing image: img1603_jpg.rf.b26650a97362c475f017f82240478722.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9996
#   Class: tank,soldiers, Probability: 0.0004
#
# Processing image: img1463_jpg.rf.f6df613f4df7c85c6f978ab72a6c4082.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0112
#   Class: tank,soldiers, Probability: 0.9888
#
# Processing image: img683_jpg.rf.e7ab90bb82bfdc4de8fe8a665aff8fba.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0113
#   Class: tank,soldiers, Probability: 0.9887
#
# Processing image: mg73_jpg.rf.1732e267667b393a714b30c3a7411074.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1391_jpg.rf.50ddeb2f273c342675c8a9bc8bb3f704.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img1125_jpg.rf.bbcb2f953c0c46e2120e3b84bceff0c5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img1910_jpg.rf.bb2844e16d3e52c5c8aa74bda2314833.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.4771
#   Class: tank,soldiers, Probability: 0.5229
#
# Processing image: img407_jpg.rf.f6ff5458af3f4882a2699ae3b418a0b8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img1483_jpg.rf.7c5f9f6cb4167ca39f88254b674cff0e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: mg181_jpg.rf.2331fedca18c2776bfba622387dbbdff.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img613_jpg.rf.1964326e4bd821ebe922188f0f8827af.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: mg178_jpg.rf.1e4428a3ccca9b8a2cf8f43359139145.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img629_jpg.rf.8f71098e0beb1e143b63c41c68c4b41b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img410_jpg.rf.5d2f55e335f4ba7779d8cb0c98c8dee8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9992
#   Class: tank,soldiers, Probability: 0.0008
#
# Processing image: img971_jpg.rf.62b215b11cdd61556702315387fc6327.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.4960
#   Class: tank,soldiers, Probability: 0.5040
#
# Processing image: img525_jpg.rf.efeb8c8ae08bcd2cda331e6628e4701c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0759
#   Class: tank,soldiers, Probability: 0.9241
#
# Processing image: mg41_jpg.rf.2797b50659722d02c0fd0eff504ae26a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.1253
#   Class: tank,soldiers, Probability: 0.8747
#
# Processing image: img129_jpg.rf.d70b6157aea5cc1f5bd3b0981441d0db.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.2897
#   Class: tank,soldiers, Probability: 0.7103
#
# Processing image: img500_jpg.rf.d909afbb60b54f5ecf998b34ee89a60d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0021
#   Class: tank,soldiers, Probability: 0.9979
#
# Processing image: img662_jpg.rf.9c86a911401afae0e0b283898a9483f5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0209
#   Class: tank,soldiers, Probability: 0.9791
#
# Processing image: img956_jpg.rf.2b09d591c71d74d570c4c6b9258cb788.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0209
#   Class: tank,soldiers, Probability: 0.9791
#
# Processing image: img200_jpg.rf.3d51863a64948c21f270d28337eba534.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img827_jpg.rf.b2fc8f1336042032891674aaf909ed71.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9987
#   Class: tank,soldiers, Probability: 0.0013
#
# Processing image: img562_jpg.rf.0f414a7551544bf67ed6b91db33d849f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9996
#   Class: tank,soldiers, Probability: 0.0004
#
# Processing image: img239_jpg.rf.9c9c20e8f2b14999c391ba6255cebc0d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0002
#   Class: tank,soldiers, Probability: 0.9998
#
# Processing image: img917_jpg.rf.bd26f3bc9d6bc11aef51ce7bfc5c01cd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0001
#   Class: tank,soldiers, Probability: 0.9999
#
# Processing image: img452_jpg.rf.ad636e9a632119b15d4dd1a8cdecc8df.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9885
#   Class: tank,soldiers, Probability: 0.0115
#
# Processing image: img1784_jpg.rf.648f2ed53494ca206bbec382584d1edb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9977
#   Class: tank,soldiers, Probability: 0.0023
#
# Processing image: img721_jpg.rf.c6692b3cda18ad1e85eaf6a191f170d2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9947
#   Class: tank,soldiers, Probability: 0.0053
#
# Processing image: img1383_jpg.rf.56ca7e3846ebd959d6ad4f37e30f6f81.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9976
#   Class: tank,soldiers, Probability: 0.0024
#
# Processing image: img261_jpg.rf.6f006f4c0d73f18f44f46d29bd79ac58.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1497_jpg.rf.7826301efc8851172175a60bf6d31709.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9932
#   Class: tank,soldiers, Probability: 0.0068
#
# Processing image: img1980_jpg.rf.05ccd2b143fce48a4cfcd817ee1265b8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9652
#   Class: tank,soldiers, Probability: 0.0348
#
# Processing image: mg170_jpg.rf.a94332ff9a498febce366c36e0a69d05.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1901_jpg.rf.6030bb5bb09899467b34826924d645fa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: mg233_jpg.rf.73aeb17b251eb1e81db1ac98956025d5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9998
#   Class: tank,soldiers, Probability: 0.0002
#
# Processing image: img1225_jpg.rf.e427f2b507b2e15bbda4f4b8b2f09579.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9966
#   Class: tank,soldiers, Probability: 0.0034
#
# Processing image: img833_jpg.rf.9181ca084ce735e3843fbac4bc33d366.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img1083_jpg.rf.a980e9bcc5f08311e4dea0beabf5c8ee.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9996
#   Class: tank,soldiers, Probability: 0.0004
#
# Processing image: img17_jpg.rf.eaad69f5807a31494507f26a8c05a54f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img514_jpg.rf.43013cae0c2cc4d35dec7df5d325eaa8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0530
#   Class: tank,soldiers, Probability: 0.9470
#
# Processing image: mg53_jpg.rf.f66fa83a29cfacbcc3c2dc2adca108b4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0002
#   Class: tank,soldiers, Probability: 0.9998
#
# Processing image: img1540_jpg.rf.8c3aa33cf7195edcbe543ddd2d7ab218.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.4987
#   Class: tank,soldiers, Probability: 0.5013
#
# Processing image: img592_jpg.rf.fe8c72f012295a04b28fec0946dd53ba.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0001
#   Class: tank,soldiers, Probability: 0.9999
#
# Processing image: img1918_jpg.rf.1622cc97db1f4e9271cae5009add3e65.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9946
#   Class: tank,soldiers, Probability: 0.0054
#
# Processing image: img169_jpg.rf.db1003c7ac77dadca30a808d9fd122a6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0001
#   Class: tank,soldiers, Probability: 0.9999
#
# Processing image: img346_jpg.rf.c62cdd4d6e555cfed88012fb7a304cb1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9665
#   Class: tank,soldiers, Probability: 0.0335
#
# Processing image: img255_jpg.rf.a232389398bc90e8f012c80aee799c4f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img590_jpg.rf.46e1f61e1f329a66bbe47fc01558aa5c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9743
#   Class: tank,soldiers, Probability: 0.0257
#
# Processing image: img1714_jpg.rf.7ef7e2a3630a0ad53e4e45dd19e86235.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.5787
#   Class: tank,soldiers, Probability: 0.4213
#
# Processing image: img112_jpg.rf.81c990e428a04f45f0d1abd7f1d2fa48.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1711_jpg.rf.8d603dd95b5b26c0c1bcbddabda69ae3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9950
#   Class: tank,soldiers, Probability: 0.0050
#
# Processing image: img124_jpg.rf.1fe1236a9cea8a8c09f0491baef04640.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.5150
#   Class: tank,soldiers, Probability: 0.4850
#
# Processing image: img212_jpg.rf.6b9e52acc8154deda30c3d945bfe4858.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0295
#   Class: tank,soldiers, Probability: 0.9705
#
# Processing image: img131_jpg.rf.f7a02c71936a3a2c56e4b9b23118e7d1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0011
#   Class: tank,soldiers, Probability: 0.9989
#
# Processing image: img598_jpg.rf.9a56295d2a8e77d0726f93c5b8458f9d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img1353_jpg.rf.7f0dc38435d44e787452e7f41bba3ff9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0122
#   Class: tank,soldiers, Probability: 0.9878
#
# Processing image: img465_jpg.rf.cf7c8817af61a25f7fad67dba8a68f80.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0009
#   Class: tank,soldiers, Probability: 0.9991
#
# Processing image: mg167_jpg.rf.be3eeaed6b0633a1d153ed61a41fd508.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1165_jpg.rf.83db379779cca1e6ed63196487d0f7e8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: mg6_jpg.rf.87686bdbd32ae1bc25a52c4e58e62ee0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1351_jpg.rf.36b78e836cfc7190c25ed3e516a1df9d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.6732
#   Class: tank,soldiers, Probability: 0.3268
#
# Processing image: mg137_jpg.rf.af83ec7e415177cc8669feed003d8ffe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img296_jpg.rf.95cc54fc7a372679c9413bb42c0327fe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1328_jpg.rf.29f6b0d1c01c92ad6f3a1b0e1670b54a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9989
#   Class: tank,soldiers, Probability: 0.0011
#
# Processing image: mg345_jpg.rf.0d76df96e9f75b94d133dc86491fc05b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img76_jpg.rf.b8ffa2705225459ba98a12fdf522b9a0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1870_jpg.rf.1cd06fb54e1e3c12e2b3b006546cfb1c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img637_jpg.rf.fe5bed746d86f710677f9b94e04aa7be.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0157
#   Class: tank,soldiers, Probability: 0.9843
#
# Processing image: img300_jpg.rf.8e8548b435df2949119a4e4a2171cfc4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0168
#   Class: tank,soldiers, Probability: 0.9832
#
# Processing image: img162_jpg.rf.e1b56a8d836935d9c9b3e7da0c0d2f3a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0004
#   Class: tank,soldiers, Probability: 0.9996
#
# Processing image: img559_jpg.rf.42d537c5a860d0ee97984fe1d61e08cd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0500
#   Class: tank,soldiers, Probability: 0.9500
#
# Processing image: img1251_jpg.rf.f4fa48daa76204e27bb3b29462be8189.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.3286
#   Class: tank,soldiers, Probability: 0.6714
#
# Processing image: img50_jpg.rf.3e0b4a99eb62b15d3b2d1b437e76416b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img70_jpg.rf.cfb0f34c30189bb29a35901b93eaa642.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0425
#   Class: tank,soldiers, Probability: 0.9575
#
# Processing image: img1507_jpg.rf.35e973bb7d06dafc586e125124141572.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.1672
#   Class: tank,soldiers, Probability: 0.8328
#
# Processing image: img392_jpg.rf.77b4d7da0aeb93222564d103319e0057.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1244_jpg.rf.166148287fb13ea7eea5f77f26f71f63.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img773_jpg.rf.169169069b71f1415a4d968d97d95336.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9864
#   Class: tank,soldiers, Probability: 0.0136
#
# Processing image: img1595_jpg.rf.b56b60fbbb1d8c210fa6d8dde3a3b9f6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9999
#   Class: tank,soldiers, Probability: 0.0001
#
# Processing image: img230_jpg.rf.cabdf9acafe45c571f3672bd42214d35.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9989
#   Class: tank,soldiers, Probability: 0.0011
#
# Processing image: mg57_jpg.rf.cf52ac6feb272ad5a56583827190e75c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0346
#   Class: tank,soldiers, Probability: 0.9654
#
# Processing image: img12_jpg.rf.b4568a8c19ab2418d1d9613b16bb18fa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: mg36_jpg.rf.5a2273c1f8edd44a4b3709d1eb689a0d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.5312
#   Class: tank,soldiers, Probability: 0.4688
#
# Processing image: img680_jpg.rf.a2a3e52e46fcf24a0af2f8e8dd37f282.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.4785
#   Class: tank,soldiers, Probability: 0.5215
#
# Processing image: img411_jpg.rf.e3251d0289d559597e3a38a0ba35aae6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.5468
#   Class: tank,soldiers, Probability: 0.4532
#
# Processing image: img333_jpg.rf.064b8e11bdbd42525f5d5f9244942b5e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0083
#   Class: tank,soldiers, Probability: 0.9917
#
# Processing image: img194_jpg.rf.64f94a5cea0372535b0788d6d5d1a0ff.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img771_jpg.rf.61f8fce3df1920d71e4fdb89cf0dff37.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.1566
#   Class: tank,soldiers, Probability: 0.8434
#
# Processing image: img1429_jpg.rf.101b60f77be26c7b072db42bb6241c97.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9905
#   Class: tank,soldiers, Probability: 0.0095
#
# Processing image: img196_jpg.rf.0e0afaabe0a7fd49613113dfc79f0185.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0013
#   Class: tank,soldiers, Probability: 0.9987
#
# Processing image: img348_jpg.rf.3afc4bd989e68774699d5516650c7d8a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: mg147_jpg.rf.2284a1dc23cf49d2ce23aca6b41975b5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0002
#   Class: tank,soldiers, Probability: 0.9998
#
# Processing image: img1569_jpg.rf.41fe8d46cb13f83a366a4fcc89694482.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.1026
#   Class: tank,soldiers, Probability: 0.8974
#
# Processing image: img378_jpg.rf.9feead8eb57d738bfaec498d3fb90d88.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9987
#   Class: tank,soldiers, Probability: 0.0013
#
# Processing image: img229_jpg.rf.ba705d338530670d049a99e87d4e2b62.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: mg257_jpg.rf.84f8600b5abef3f57200e285ebed401f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1381_jpg.rf.533fc12ce49fcbf91640538087cdb4cf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9907
#   Class: tank,soldiers, Probability: 0.0093
#
# Processing image: img865_jpg.rf.18486459b10244e58cd302552e648954.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0001
#   Class: tank,soldiers, Probability: 0.9999
#
# Processing image: img210_jpg.rf.fc4de0d0e42ebf9239342cc0ef175fdb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0032
#   Class: tank,soldiers, Probability: 0.9968
#
# Processing image: img2009_jpg.rf.4f39a9060f3c98b01ae5f51b9adad24c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9999
#   Class: tank,soldiers, Probability: 0.0001
#
# Processing image: img848_jpg.rf.e54f454597e21fc555f478482ea334db.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.4646
#   Class: tank,soldiers, Probability: 0.5354
#
# Processing image: img1025_jpg.rf.622849e1fdd808bc292ec589bb7ff331.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.2115
#   Class: tank,soldiers, Probability: 0.7885
#
# Processing image: img797_jpg.rf.3f965376cb4912ef3ba300ba446275cd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9984
#   Class: tank,soldiers, Probability: 0.0016
#
# Processing image: img1505_jpg.rf.827afaf08089f4de4bb938e17a2e28d7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9677
#   Class: tank,soldiers, Probability: 0.0323
#
# Processing image: img838_jpg.rf.bd86a81edbc1905ff251742115c3588f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9875
#   Class: tank,soldiers, Probability: 0.0125
#
# Processing image: img697_jpg.rf.647e8e0015080e7fed886b4823e72a33.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9924
#   Class: tank,soldiers, Probability: 0.0076
#
# Processing image: img1108_jpg.rf.cb7dc5c81b50313ae8abb1e27ef38dd3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img1702_jpg.rf.31298fb3655eeb24c069e9c778312a50.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img348_jpg.rf.6921c1c6d79b21990d448fbcfc42400b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.2812
#   Class: tank,soldiers, Probability: 0.7188
#
# Processing image: img266_jpg.rf.35841ff348df891a560cd4558803a050.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0004
#   Class: tank,soldiers, Probability: 0.9996
#
# Processing image: img536_jpg.rf.2333a9eb2cbd27a2c9a0843d0f297602.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img546_jpg.rf.02eb1bca8e1378a0e15921ce06c134b9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9902
#   Class: tank,soldiers, Probability: 0.0098
#
# Processing image: img554_jpg.rf.af2f3c6acf14b343b7ab8c0747defd5e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9998
#   Class: tank,soldiers, Probability: 0.0002
#
# Processing image: mg4_jpg.rf.77d009964954f7fb51d373149d1666c2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0048
#   Class: tank,soldiers, Probability: 0.9952
#
# Processing image: mg327_jpg.rf.dc527a9b1f0a72b114347a94975a877e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0013
#   Class: tank,soldiers, Probability: 0.9987
#
# Processing image: img1996_jpg.rf.b2c08e3e7c40709b21684d6908f4e0f2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: mg179_jpg.rf.d045e11530e3312cb7cb53544de20297.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0089
#   Class: tank,soldiers, Probability: 0.9911
#
# Processing image: img366_jpg.rf.dd97f010a82570e3de377f45ea92ef1f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0415
#   Class: tank,soldiers, Probability: 0.9585
#
# Processing image: mg210_jpg.rf.2f49056559db8a9df09860c3f9ededcd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0001
#   Class: tank,soldiers, Probability: 0.9999
#
# Processing image: img1368_jpg.rf.7a41be9d5ee9be98d68cac8f8bb6c7dc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9991
#   Class: tank,soldiers, Probability: 0.0009
#
# Processing image: img35_jpg.rf.fb0f1980a507b028986244c01050cfb2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0001
#   Class: tank,soldiers, Probability: 0.9999
#
# Processing image: img390_jpg.rf.1aabd62bbdceaea4083d07a8f00173f4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: mg48_jpg.rf.bde58eb1ff421f8287719a0911fd1042.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img965_jpg.rf.433a8ce192a9a8044bf522978c8c0820.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9722
#   Class: tank,soldiers, Probability: 0.0278
#
# Processing image: mg80_jpg.rf.2dfea27be8a237de33c86d9f73935493.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0038
#   Class: tank,soldiers, Probability: 0.9962
#
# Processing image: img314_jpg.rf.2dbe455aae96b8bd99d62cb444e04002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0514
#   Class: tank,soldiers, Probability: 0.9486
#
# Processing image: img155_jpg.rf.03467a6e9c8b1e448eb540e54b21abe7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img267_jpg.rf.552a7eee287145098ccfbd14b5ca6c8d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1340_jpg.rf.2d7a75647ed49274bff9d7bd590a3b3a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0012
#   Class: tank,soldiers, Probability: 0.9988
#
# Processing image: img363_jpg.rf.1c26e89e3a44ec30e41ba93399c60cca.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9999
#   Class: tank,soldiers, Probability: 0.0001
#
# Processing image: img1431_jpg.rf.c5936c85fcb21790d390053912394899.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9093
#   Class: tank,soldiers, Probability: 0.0907
#
# Processing image: img223_jpg.rf.d0a42ca78456f8b408fa93ed218299d5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0042
#   Class: tank,soldiers, Probability: 0.9958
#
# Processing image: img446_jpg.rf.a49be2df300ef431410d36fd521ac3cf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.1052
#   Class: tank,soldiers, Probability: 0.8948
#
# Processing image: img78_jpg.rf.4f9a149fd950279573d9dce1e2bdf7b5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0001
#   Class: tank,soldiers, Probability: 0.9999
#
# Processing image: img165_jpg.rf.3d2a94ced5cfff6a64964d625b6c548a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.1164
#   Class: tank,soldiers, Probability: 0.8836
#
# Processing image: img356_jpg.rf.a65ed4fcd3c77181841f663c8ba681df.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img944_jpg.rf.3a62aa09bca16d42a6fbf61271ced337.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.8293
#   Class: tank,soldiers, Probability: 0.1707
#
# Processing image: img1143_jpg.rf.c66ca208dd584f02441a765660fca45c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img281_jpg.rf.85a8c4b52d22f9773d92a2267ce3d1ab.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0001
#   Class: tank,soldiers, Probability: 0.9999
#
# Processing image: img688_jpg.rf.f3a4595982c261302cadcb162cf5d271.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9805
#   Class: tank,soldiers, Probability: 0.0195
#
# Processing image: img438_jpg.rf.6ff04d41666a03df3f055e1512bcf764.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.7597
#   Class: tank,soldiers, Probability: 0.2403
#
# Processing image: img550_jpg.rf.d64f66f74eb24fc8bf3828629f998cb4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img226_jpg.rf.3e3783c65104b2a5809f50ff01ccf72b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1546_jpg.rf.bbf599c56faaa893d625ca8ba336ba53.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0079
#   Class: tank,soldiers, Probability: 0.9921
#
# Processing image: img147_jpg.rf.57570784e9073096bbae21839bf76fbb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.2662
#   Class: tank,soldiers, Probability: 0.7338
#
# Processing image: img510_jpg.rf.8bb81c071cf46c980d6c56a9bc16ed82.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.7308
#   Class: tank,soldiers, Probability: 0.2692
#
# Processing image: img31_jpg.rf.d7c2c7ad23d7fc7ac60d74b02028cf9f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0003
#   Class: tank,soldiers, Probability: 0.9997
#
# Processing image: mg254_jpg.rf.63950026e7edfecf0f73cc852c568ba6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img544_jpg.rf.b1f9edbd087a4879bd351176370c2ecd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.7146
#   Class: tank,soldiers, Probability: 0.2854
#
# Processing image: img1215_jpg.rf.cb0e66d6760a47ccdca8d55514901d6e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img73_jpg.rf.dbb45f6bc42a0892a4b3bc4d0e326ef7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9907
#   Class: tank,soldiers, Probability: 0.0093
#
# Processing image: mg169_jpg.rf.b5ef885d900255d5eac2a72fb69d3d1c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0019
#   Class: tank,soldiers, Probability: 0.9981
#
# Processing image: img1623_jpg.rf.c3444828cb4ea15cfb110040fa74eb45.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img2016_jpg.rf.5fd9f9185a040be7f40ba9ce8e5e7a0c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9969
#   Class: tank,soldiers, Probability: 0.0031
#
# Processing image: img581_jpg.rf.9ab6db00855b26f04bd88fff7d540f06.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.5408
#   Class: tank,soldiers, Probability: 0.4592
#
# Processing image: img502_jpg.rf.be8a8e4c6c505a5f493b635384c42519.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1950_jpg.rf.197eb432e351fe9de017c65faba83cec.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9999
#   Class: tank,soldiers, Probability: 0.0001
#
# Processing image: img594_jpg.rf.d7a3fea3819b838ff2ed8c0791b359f6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9999
#   Class: tank,soldiers, Probability: 0.0001
#
# Processing image: img1638_jpg.rf.202cfd257a2e5d20813f8a725720a0d4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.7850
#   Class: tank,soldiers, Probability: 0.2150
#
# Processing image: img962_jpg.rf.e92535690dc75c7dce9e69ceea244656.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9917
#   Class: tank,soldiers, Probability: 0.0083
#
# Processing image: img179_jpg.rf.b109b2628cb9ba86add7b0d204240cf5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img138_jpg.rf.2b74aceaa4c52625effa5749dcdae369.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0006
#   Class: tank,soldiers, Probability: 0.9994
#
# Processing image: img1070_jpg.rf.c9327ade6a7ae2a27d9376d6ea7fdf98.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img443_jpg.rf.5bbeadbcc768724ce753a89f6ee29d5c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0116
#   Class: tank,soldiers, Probability: 0.9884
#
# Processing image: img703_jpg.rf.50b3680189014b846ff5ea846245f663.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9969
#   Class: tank,soldiers, Probability: 0.0031
#
# Processing image: img608_jpg.rf.b325ae945ca0eb4acadece2539506031.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9489
#   Class: tank,soldiers, Probability: 0.0511
#
# Processing image: img130_jpg.rf.f549fccaa8e6b230b900a9e26be3cb76.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.8758
#   Class: tank,soldiers, Probability: 0.1242
#
# Processing image: img739_jpg.rf.fec4aa4043a3a62f98732829f066e65a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.2507
#   Class: tank,soldiers, Probability: 0.7493
#
# Processing image: img996_jpg.rf.eb6ca07097b60d3f0c724bc8dcf8e990.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img1994_jpg.rf.35e347f33f7dc1e1e4faa67a9e7d5f99.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img1999_jpg.rf.9e08d8174c10b1f74506065bcc32a665.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9997
#   Class: tank,soldiers, Probability: 0.0003
#
# Processing image: img1909_jpg.rf.a1ff0b83f31cbda4a1ed10f89c86e3c5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0728
#   Class: tank,soldiers, Probability: 0.9272
#
# Processing image: img1058_jpg.rf.a455ff8aedeecab726bf90b080e8a8ab.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img494_jpg.rf.5b4e4d9a32dbc6a131388ba6c5082e1a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0492
#   Class: tank,soldiers, Probability: 0.9508
#
# Processing image: img1555_jpg.rf.11df8767d9ac14610829ccac7207bbf1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.6662
#   Class: tank,soldiers, Probability: 0.3338
#
# Processing image: img1931_jpg.rf.c6a6532edd816403eef6d0bdfe274b5b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0988
#   Class: tank,soldiers, Probability: 0.9012
#
# Processing image: img1924_jpg.rf.e5c4de7e46e09d811b2876c70b7f49a9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img1564_jpg.rf.5ca4c46c7de935109e783601a9c145cd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9981
#   Class: tank,soldiers, Probability: 0.0019
#
# Processing image: img885_jpg.rf.1a8f39b6a6ff664bff786a6120fb6419.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9861
#   Class: tank,soldiers, Probability: 0.0139
#
# Processing image: img359_jpg.rf.f51eea84e2491a42baa0205c5d8421b1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img936_jpg.rf.16fcc62d7727f193706bc65ae0387a20.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9906
#   Class: tank,soldiers, Probability: 0.0094
#
# Processing image: img302_jpg.rf.dd398052e4ebc5697e9a1096b50add65.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9989
#   Class: tank,soldiers, Probability: 0.0011
#
# Processing image: img554_jpg.rf.a454719d61f0f95ab0e6007b52aaec3b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0195
#   Class: tank,soldiers, Probability: 0.9805
#
# Processing image: img1265_jpg.rf.404b672af03e6fdb4d13822c5aaaf542.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0962
#   Class: tank,soldiers, Probability: 0.9038
#
# Processing image: img612_jpg.rf.aded170bdc3466129b19109c9c084713.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9999
#   Class: tank,soldiers, Probability: 0.0001
#
# Processing image: img290_jpg.rf.692883eec204d62446621ff63890b768.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1212_jpg.rf.dbb18a458135f45831612d5085063bc2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9672
#   Class: tank,soldiers, Probability: 0.0328
#
# Processing image: mg102_jpg.rf.8cf661c479f0d39efceffb68930cac5c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0021
#   Class: tank,soldiers, Probability: 0.9979
#
# Processing image: img946_jpg.rf.e5728afe88382f37b0112169cfa0582e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0006
#   Class: tank,soldiers, Probability: 0.9994
#
# Processing image: img1538_jpg.rf.aada4d6e7ada85997b080a0afea8c645.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0030
#   Class: tank,soldiers, Probability: 0.9970
#
# Processing image: mg92_jpg.rf.860431c78fa4c0207ea92708b2e86de9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.2262
#   Class: tank,soldiers, Probability: 0.7738
#
# Processing image: mg211_jpg.rf.14f02db5e88f1176b0e3878403bca6b1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: mg177_jpg.rf.cf4a477295e8cb5f3c23af873047919f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.2113
#   Class: tank,soldiers, Probability: 0.7887
#
# Processing image: img1185_jpg.rf.19fae91e2c6472f6f0b4caa71cb98bb6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9991
#   Class: tank,soldiers, Probability: 0.0009
#
# Processing image: img870_jpg.rf.aeaae1f9cb96ac7dfa89852f245c41c9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9970
#   Class: tank,soldiers, Probability: 0.0030
#
# Processing image: img984_jpg.rf.a66a32b28ba1cd67053a39a0a4ea3af2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9994
#   Class: tank,soldiers, Probability: 0.0006
#
# Processing image: mg205_jpg.rf.ad4d4533816a4facc1c72e91d60f3b4a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0161
#   Class: tank,soldiers, Probability: 0.9839
#
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.1556
#   Class: tank,soldiers, Probability: 0.8444
#
# Processing image: img616_jpg.rf.177cc26ae7a86e786962e5857ecfac59.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9769
#   Class: tank,soldiers, Probability: 0.0231
#
# Processing image: img204_jpg.rf.902b608abd6eba2fd50c3db31a2c182a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.3009
#   Class: tank,soldiers, Probability: 0.6991
#
# Processing image: img840_jpg.rf.9b5945aff0d7ab94b62030ba94f82c9a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0025
#   Class: tank,soldiers, Probability: 0.9975
#
# Processing image: img398_jpg.rf.25dd47cfbbc6d00961e4cce1fac78a5f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.4937
#   Class: tank,soldiers, Probability: 0.5063
#
# Processing image: img1209_jpg.rf.cee6b88352836d7e789d2ee961b0f843.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0134
#   Class: tank,soldiers, Probability: 0.9866
#
# Processing image: img252_jpg.rf.eb1e90a28a72c69a3122c7a0bda21814.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0064
#   Class: tank,soldiers, Probability: 0.9936
#
# Processing image: img175_jpg.rf.3dadfbb12d11f17bc72b09ebacffef58.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0050
#   Class: tank,soldiers, Probability: 0.9950
#
# Processing image: img975_jpg.rf.f5aec319d0c9b21a7227674df621903c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.1980
#   Class: tank,soldiers, Probability: 0.8020
#
# Processing image: img1339_jpg.rf.4804411b54ee2a3bef7e981cf3785157.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0010
#   Class: tank,soldiers, Probability: 0.9990
#
# Processing image: img1794_jpg.rf.14384f61632cfca8af01d7f265fcadd3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9999
#   Class: tank,soldiers, Probability: 0.0001
#
# Processing image: img815_jpg.rf.0e4a0738f9949fe098cdf03d768f57f4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9197
#   Class: tank,soldiers, Probability: 0.0803
#
# Processing image: img271_jpg.rf.3c21fadb3afd076c51f65bf743ef8599.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0031
#   Class: tank,soldiers, Probability: 0.9969
#
# Processing image: img652_jpg.rf.13f4b8764948e3c12bc7908d9aee4850.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9888
#   Class: tank,soldiers, Probability: 0.0112
#
# Processing image: img1005_jpg.rf.0213eaba8cb73291dfbd2de724e90795.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9849
#   Class: tank,soldiers, Probability: 0.0151
#
# Processing image: img147_jpg.rf.a7948db5058ea2747344c4101852af32.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0019
#   Class: tank,soldiers, Probability: 0.9981
#
# Processing image: img409_jpg.rf.107229ef931044c979818fafe0be8679.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.3685
#   Class: tank,soldiers, Probability: 0.6315
#
# Processing image: img596_jpg.rf.ed69c5742eb52842aa44da4e12bcf83b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: mg95_jpg.rf.9a8bbe062bfdf73bfc5eaf7576bccf81.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img1241_jpg.rf.fde16d92e5d0296f13b96045adf4f459.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.6789
#   Class: tank,soldiers, Probability: 0.3211
#
# Processing image: img708_jpg.rf.ce2772d33449b4508c61aaea483844bd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9407
#   Class: tank,soldiers, Probability: 0.0593
#
# Processing image: img1198_jpg.rf.bb11c5eb5c1b54a0db606db924150262.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0283
#   Class: tank,soldiers, Probability: 0.9717
#
# Processing image: img486_jpg.rf.2ad06e2b37ab90ccde47e429819cdbdf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9955
#   Class: tank,soldiers, Probability: 0.0045
#
# Processing image: mg5_jpg.rf.cca4d7ef9f381338b820682885dfbb6d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0027
#   Class: tank,soldiers, Probability: 0.9973
#
# Processing image: img696_jpg.rf.ee65ec7fd189eb6305dc3c92927806e0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9998
#   Class: tank,soldiers, Probability: 0.0002
#
# Processing image: img2027_jpg.rf.9af0d61e9f358e0b08a96c77bd27c9ca.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9563
#   Class: tank,soldiers, Probability: 0.0437
#
# Processing image: mg112_jpg.rf.c8add808f4db91487c102347d29d4ed6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0001
#   Class: tank,soldiers, Probability: 0.9999
#
# Processing image: mg110_jpg.rf.cca67fad2a4a7231f9f2b28cd8a11e79.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0001
#   Class: tank,soldiers, Probability: 0.9999
#
# Processing image: mg263_jpg.rf.bb8b7a15a5658783bd46f746702f7f7c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0021
#   Class: tank,soldiers, Probability: 0.9979
#
# Processing image: img817_jpg.rf.58aa6e62f27b64a96fd4f23ea6f972fa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9952
#   Class: tank,soldiers, Probability: 0.0048
#
# Processing image: img846_jpg.rf.3f5eeda9621abd6042bfb7f207ce50c9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9998
#   Class: tank,soldiers, Probability: 0.0002
#
# Processing image: img1574_jpg.rf.321ec3934ae74994532a59003ba6aa3f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.7820
#   Class: tank,soldiers, Probability: 0.2180
#
# Processing image: img578_jpg.rf.01412d6e9e0afcc9874518e2e73769e9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0009
#   Class: tank,soldiers, Probability: 0.9991
#
# Processing image: img165_jpg.rf.6facedb7999fdadeaa0754c3fb11ef45.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9928
#   Class: tank,soldiers, Probability: 0.0072
#
# Processing image: img1991_jpg.rf.9010dccc32d2e8e3625d4806be339d0b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0014
#   Class: tank,soldiers, Probability: 0.9986
#
# Processing image: img257_jpg.rf.6ed4cee7a3b344fe3f43d8388d644e7d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: mg200_jpg.rf.b765253b7f3f4afce8d9586cbdf9f783.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0070
#   Class: tank,soldiers, Probability: 0.9930
#
# Processing image: img1113_jpg.rf.232f31a052501ec353fb8c60784ca731.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0225
#   Class: tank,soldiers, Probability: 0.9775
#
# Processing image: img1906_jpg.rf.136f17495619dc78c794968ad723921d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img1395_jpg.rf.2c14c5d006bbc3445a1faa35c4d80720.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9969
#   Class: tank,soldiers, Probability: 0.0031
#
# Processing image: img1149_jpg.rf.206c759557d0b4d9ef80caf921150470.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.8384
#   Class: tank,soldiers, Probability: 0.1616
#
# Processing image: img623_jpg.rf.23488a8735e05f039bb1e4f6eeee3c42.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9342
#   Class: tank,soldiers, Probability: 0.0658
#
# Processing image: img184_jpg.rf.35fb8ccf320c3247e3d7d3b1a39a7f14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.6090
#   Class: tank,soldiers, Probability: 0.3910
#
# Processing image: mg183_jpg.rf.54cdbefaab5a99dcba42a37efe6e80e7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0759
#   Class: tank,soldiers, Probability: 0.9241
#
# Processing image: img294_jpg.rf.53557b5013afaf1ada19c1ac4b55eaa5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0700
#   Class: tank,soldiers, Probability: 0.9300
#
# Processing image: img39_jpg.rf.3256fe9251fd1580633b4a401136900e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0015
#   Class: tank,soldiers, Probability: 0.9985
#
# Processing image: img467_jpg.rf.1d3e786705d4516465f6c8897b3e90fa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9992
#   Class: tank,soldiers, Probability: 0.0008
#
# Processing image: img1787_jpg.rf.a13eed40087efe34906cb75d9d78ab9d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img1195_jpg.rf.8ea0bab74451063634cd3236d35aa507.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9995
#   Class: tank,soldiers, Probability: 0.0005
#
# Processing image: img1343_jpg.rf.d55a4d2e8379a31a31b308304c274cc2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9995
#   Class: tank,soldiers, Probability: 0.0005
#
# Processing image: img1641_jpg.rf.b8549d91b049af5da5301f0bd4d2bb3d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9989
#   Class: tank,soldiers, Probability: 0.0011
#
# Processing image: mg314_jpg.rf.ab545927aac9feda283819db182ac0ea.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: mg85_jpg.rf.ac31114ccc78251345b656dbaadd2a3b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img546_jpg.rf.a624379a3a7126b61d242e3f1a15d120.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0132
#   Class: tank,soldiers, Probability: 0.9868
#
# Processing image: mg38_jpg.rf.5bf232f458023af4e4f775ab6e098d25.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img842_jpg.rf.0acf7fb6fdfcf00407a1ac568a83ac98.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9813
#   Class: tank,soldiers, Probability: 0.0187
#
# Processing image: img1460_jpg.rf.1675bd13e80418e28692a7b3d9368cc1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9976
#   Class: tank,soldiers, Probability: 0.0024
#
# Processing image: img1075_jpg.rf.edf2bd256ee511ababd338a19e8265d2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 1.0000
#   Class: tank,soldiers, Probability: 0.0000
#
# Processing image: img395_jpg.rf.a5f340de11a9006974ef070df2174c6b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9968
#   Class: tank,soldiers, Probability: 0.0032
#
# Processing image: img1382_jpg.rf.e985bdd9d17da2d7d209bb5635fd19dd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9979
#   Class: tank,soldiers, Probability: 0.0021
#
# Processing image: img347_jpg.rf.c0622abc31979a4ed450bb35c51691b2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img619_jpg.rf.94a9fc797c5f0934e9d4e09804d129bd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.5058
#   Class: tank,soldiers, Probability: 0.4942
#
# Processing image: img217_jpg.rf.be4bf017fb058cbc0cf2a08f71c7e283.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0000
#   Class: tank,soldiers, Probability: 1.0000
#
# Processing image: img677_jpg.rf.489021bc87617e5af6c4324064382f94.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0952
#   Class: tank,soldiers, Probability: 0.9048
#
# Processing image: img2_jpg.rf.e8cf7574b8c34c23a5e86ea3c7ecea01.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0007
#   Class: tank,soldiers, Probability: 0.9993
#
# Processing image: img576_jpg.rf.096f9b455c07f1f9e06a9fcff6d9a9aa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9984
#   Class: tank,soldiers, Probability: 0.0016
#
# Processing image: mg33_jpg.rf.0414ecae4dd65c41b1013827ececfe14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0382
#   Class: tank,soldiers, Probability: 0.9618
#
# Processing image: img899_jpg.rf.c4d8954fae5eaddf850f120c037ac6d7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9980
#   Class: tank,soldiers, Probability: 0.0020
#
# Processing image: img385_jpg.rf.0ee2dd391ff001865ed6f14f9a5933d8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.8520
#   Class: tank,soldiers, Probability: 0.1480
#
# Processing image: img741_jpg.rf.a8cbeddaf344d88c43bdc926d82e72f0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted Class: tank,soldiers
#   Class: base,plane, Probability: 0.0007
#   Class: tank,soldiers, Probability: 0.9993
#
# Processing image: img1322_jpg.rf.96d3af41ae60611678d803398c98535d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9961
#   Class: tank,soldiers, Probability: 0.0039
#
# Processing image: img1732_jpg.rf.c5576c168910ce58a6b87cc4e284df36.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted Class: base,plane
#   Class: base,plane, Probability: 0.9986
#   Class: tank,soldiers, Probability: 0.0014
